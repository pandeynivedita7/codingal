# %% [markdown]
# <a href="https://colab.research.google.com/github/pandeynivedita7/codingal/blob/main/DSCM17L2A1_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Titanic = pd.read_csv(r"Titanic.csv")
Titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man           1  NaN  Southampton    no      0
# 1  woman           0    C    Cherbourg   yes      0
# 2  woman           0  NaN  Southampton   yes      1
# 3  woman           0    C  Southampton   yes      0
# 4    man           1  NaN  Southampton    no      1

# %%
Titanic.shape
# Out:
# Shape of the dataset: (891, 15)
# (891, 15)

# %%
Titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.heatmap(Titanic.isnull(), cmap="spring")
# Out:
# <Axes: >

# %%
#Since the highest null values are found in "deck" coloumn so dropping it respectively..

# %%
#Printing the original Dataset again

Titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man           1  NaN  Southampton    no      0
# 1  woman           0    C    Cherbourg   yes      0
# 2  woman           0  NaN  Southampton   yes      1
# 3  woman           0    C  Southampton   yes      0
# 4    man           1  NaN  Southampton    no      1

# %%
#Dropping the deck coloumn

# %%
Titanic.drop("deck", axis=1, inplace=True)

# %%
#Printing the Dataset after dropping the coloumn

# %%
Titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man           1  Southampton    no      0
# 1  woman           0    Cherbourg   yes      0
# 2  woman           0  Southampton   yes      1
# 3  woman           0  Southampton   yes      0
# 4    man           1  Southampton    no      1

# %%
Titanic.dropna(inplace=True)

# %%
sns.heatmap(Titanic.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
#As you can see no null values found

# %%
#Now all the null values have been removed "CHECK"

Titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
#Simplifying the data more by converting the string data types to integer.

# %%
pd.get_dummies(Titanic["sex"]).head()
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False
# 3    True  False
# 4   False   True

# %%
sex = pd.get_dummies(Titanic["sex"], drop_first=True)

# %%
sex.head(4)
# Out:
#     male
# 0   True
# 1  False
# 2  False
# 3  False

# %%
#If we observe embark_town there are only two data types present which can be split in the form of integers

# %%
pd.get_dummies(Titanic["embarked"]).head(4)
# Out:
#        C      Q      S
# 0  False  False   True
# 1   True  False  False
# 2  False  False   True
# 3  False  False   True

# %%
arked = pd.get_dummies(Titanic["embarked"], drop_first=True)

# %%
#Similarly for pclass

# %%
pclass = pd.get_dummies(Titanic["pclass"], drop_first=True)

# %%
pclass.head(4)
# Out:
#        2      3
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False  False

# %%
Titanic = pd.concat([Titanic, sex, pclass], axis=1)

# %%
#Printing the Updated Dataset

# %%
Titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone   male      2      3
# 0    man           1  Southampton    no      0   True  False   True
# 1  woman           0    Cherbourg   yes      0  False  False  False
# 2  woman           0  Southampton   yes      1  False  False   True
# 3  woman           0  Southampton   yes      0  False  False  False
# 4    man           1  Southampton    no      1   True  False   True

# %%
Titanic = pd.read_csv(r"Titanic.csv")
Titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man           1  NaN  Southampton    no      0
# 1  woman           0    C    Cherbourg   yes      0
# 2  woman           0  NaN  Southampton   yes      1
# 3  woman           0    C  Southampton   yes      0
# 4    man           1  NaN  Southampton    no      1
