# %%
from ultralytics import YOLO
print("Ultralytics YOLO installed successfully!")
model = YOLO('yolov8n.pt')  # YOLOv8 nano model
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load the pretrained YOLO model
model = YOLO("yolov8n.pt")  # Replace 'yolov8n.pt' with your custom model if needed

def detect_action(model, image_path):
    results = model.predict(source=image_path, conf=0.25, save=False)
    result = results[0]
    detections = [
        (model.names[int(box.cls[0])], float(box.conf[0]))
        for box in result.boxes
    ]

    # Further processing...
    print("Detections:", detections)

# Example test
image_path = "example 1.jpg"  # Replace with your test image
detect_action(model, image_path)
# Out:
# Ultralytics YOLO installed successfully!
#
# image 1/1 C:\Users\hp\example 1.jpg: 480x640 2 persons, 1 handbag, 1 tennis racket, 96.2ms
# Speed: 4.0ms preprocess, 96.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detections: [('person', 0.942900538444519), ('person', 0.8625512719154358), ('handbag', 0.3090418577194214), ('tennis racket', 0.2852526903152466)]
