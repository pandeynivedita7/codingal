# %%
import numpy as np # Import the numpy library for numerical operations
import seaborn as sns # Import the seaborn library for data visualization
import matplotlib.pyplot as plt # Import the matplotlib.pyplot library for plotting
from sklearn.datasets import load_breast_cancer # Import the load_breast_cancer dataset from scikit-learn

dataset = load_breast_cancer() # Load the breast cancer dataset

# %%
sns.set_style('dark') # Set the seaborn style to 'dark'
import matplotlib as mpl # Import matplotlib as mpl
# Use a custom matplotlib style from a URL
mpl.style.use(['https://gist.githubusercontent.com/BrendanMartin/01e71bb9550774e2ccff3af7574c0020/raw/6fa9681c7d0232d34c9271de9be150e584e606fe/lds_default.mplstyle'])
# Update matplotlib parameters for figure size and title padding
mpl.rcParams.update({"figure.figsize": (8,6), "axes.titlepad": 22.0})

# %%
# Print the target variable names in the dataset
print('Target variables  : ', dataset['target_names'])

# Get unique values and their counts of the target variable
(unique, counts) = np.unique(dataset['target'], return_counts=True)

# Print the unique values of the target variable
print('Unique values of the target variable', unique)
# Print the counts of each unique value of the target variable
print('Counts of the target variable :', counts)
# Out:
# Target variables  :  ['malignant' 'benign']
# Unique values of the target variable [0 1]
# Counts of the target variable : [212 357]

# %%
# Create a bar plot using seaborn
# x-axis represents the target variable names
# y-axis represents the counts of each target variable
sns.barplot(x=dataset['target_names'], y=counts)
# Set the title of the plot
plt.title('Target variable counts in dataset')
# Display the plot
plt.show()
